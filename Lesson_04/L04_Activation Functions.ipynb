# %%
# run this cell to install the course package and its dependencies, add --user to install in CoCalc base environment
# you don't need run this cell every time unless you want to upgrade the package to the latest version

# use this line to install from GitHub
# %pip install -q git+https://github.com/DataScienceUWL/DS776.git@main#egg=introdl\&subdirectory=introdl

# use this line to install from local folder, change the path as needed
# %pip install -q ../introdl
# Out:
# WARNING: Error parsing dependencies of pytorch-lightning: .* suffix can only be used with `==` or `!=` operators
#     torch (>=1.9.*)
#            ~~~~~~^
# Note: you may need to restart the kernel to use updated packages.

# %%
# imports

from introdl.visul import activations_widget, plot_activation_functions

# %% [markdown]
# ## Explore Various Activation Functions
#
# Below is a widget you can use to plot selected activation functions and their derivatives.  We use the widget in the video for this notebook, but if your notebook environment doesn't support widgets (`ipywdiget` must be installed) you can produce individual plots as shown further below.

# %%
activations_widget()
# Out:
# interactive(children=(SelectMultiple(description='Activations', index=(0,), options=('sigmoid', 'ReLU', 'tanh'…

# %% [markdown]
# ### Plotting without the widget

# %%
help(plot_activation_functions)
# Out:
# Help on function plot_activation_functions in module introdl.visul.visul:
#
# plot_activation_functions(selected_activations)
#     Plots the activation functions and their derivatives.
#
#     Parameters:
#     - selected_activations (str or list): A string or a list of activation function names.
#         Possible activation function names: 'sigmoid', 'ReLU', 'tanh', 'LeakyReLU', 'GELU', 'swish'
#
#     Returns:
#     None

# %%
plot_activation_functions(['sigmoid', 'tanh'])

# %%
plot_activation_functions('ReLU')
