# %% [markdown]
# ### Lesson 6 Reading Quiz
#
# Read Inside Deep Learning Chapter 8 - ...
#
# #### 1. What is the main purpose of object detection in deep learning?
# A. Classifying the whole image
# B. Identifying and localizing multiple objects within an image
# C. Enhancing image resolution
# D. Compressing image data
#
# ---
#
# #### 2. How does image segmentation differ from object detection?
# A. It involves labeling individual pixels instead of bounding objects
# B. It uses linear layers exclusively
# C. It only detects single objects
# D. It reduces the image to grayscale
#
# ---
#
# #### 3. Which architecture is commonly used for image segmentation tasks in deep learning?
# A. Faster R-CNN
# B. U-Net
# C. ResNet
# D. VGGNet
#
# ---
#
# #### 4. What is the role of transposed convolutions in image segmentation?
# A. To reduce the resolution of an image
# B. To maintain original image size while adding detail
# C. To classify bounding boxes
# D. To create overlapping image regions
#
# ---
#
# #### 5. Why are bounding boxes typically used in object detection tasks?
# A. They make labeling objects easier than pixel-level segmentation
# B. They increase computational complexity
# C. They only allow for grayscale images
# D. They are used solely for small object detection
#
# ---
#
# #### 6. What is a primary advantage of using Faster R-CNN in object detection?
# A. It reduces the need for bounding boxes
# B. It is faster than traditional R-CNN by using region proposals
# C. It simplifies image segmentation
# D. It uses less memory than CNNs
#
# ---
#
# #### 7. In the context of object detection, what is the purpose of non-maximum suppression?
# A. To avoid overlapping bounding boxes
# B. To enhance small objects
# C. To label each pixel separately
# D. To convert images to grayscale
#
# ---
#
# #### 8. Why is image segmentation considered more costly than object detection?
# A. It requires per-pixel labeling, which is labor-intensive
# B. It only applies to high-resolution images
# C. It needs fewer training images but more epochs
# D. It does not support transposed convolutions
#
# ---
#
# #### 9. Which of the following is a key challenge in training object detection models?
# A. Balancing between detecting small and large objects within an image
# B. Limiting the model to a single object class
# C. Reducing image resolution for faster computation
# D. Avoiding the use of convolutional layers
#
# ---
#
# #### 10. What makes U-Net a preferred architecture for medical image segmentation?
# A. It only requires a few images to train
# B. It captures both fine and coarse details of the image
# C. It is designed specifically for bounding box detection
# D. It automatically detects tumors
#
# ---
