# %%
# !pip install -q ../introdl/

# %%
# imports and configuration

# uncomment to use a custom environment file
# from dotenv import load_dotenv
# load_dotenv('../main.env')

import os
from pathlib import Path

MODELS_PATH = Path(os.getenv('MODELS_PATH'))
DATA_PATH = Path(os.getenv('DATA_PATH'))
TORCH_HOME = Path(os.getenv('TORCH_HOME'))

print(f'{MODELS_PATH=}')
print(f'{DATA_PATH=}')
print(f'{TORCH_HOME=}')

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision.datasets import ImageFolder
from torch.optim.lr_scheduler import OneCycleLR

import torchvision.models as models
import torchvision.transforms.v2 as T

from torchinfo import summary

from introdl.utils import get_device, load_results, load_model
from introdl.idlmam import train_network
from introdl.visul import plot_training_metrics, plot_transformed_images, create_image_grid, evaluate_classifier

sns.set_theme(style='whitegrid')
plt.rcParams['figure.figsize'] = [8, 6]  # Set the default figure size (width, height) in inches
# Out:
# MODELS_PATH=WindowsPath('C:/Users/bagge/My Drive/Python_Projects/DS776_Develop_Project/models')
# DATA_PATH=WindowsPath('C:/Users/bagge/My Drive/Python_Projects/DS776_Develop_Project/data')
# TORCH_HOME=WindowsPath('C:/Users/bagge/My Drive/Python_Projects/DS776_Develop_Project/downloads')

# %% [markdown]
# # Transfer Learning
#
# In this notebook we'll illustrate transfer learning and fine-tuning on a small Kaggle dataset.  We'll use both the same ResNet18 model as in the textbook and a more advanced ConvNeXt model.

# %% [markdown]
# ## Cats, Dogs, and Foxes Dataset
#
# This small, balanced [dataset on Kaggle](https://www.kaggle.com/datasets/snmahsa/animal-image-dataset-cats-dogs-and-foxes) contains 310 images of cats, dogs, and foxes.  That's far too few images to train a decent model from scratch, but by starting with a model that has been pretrained we can adapt it to classifying our data.  Most pre-trained image classification models have been trained on [Imagenet](https://www.image-net.org/) which has 1.28 million training images across 1,000 classes that cover a wide variety of objects, animals, and scenes.  Specifically, Imagenet includes images of cats, dogs, and foxes but not the same images as in the Kaggle dataset.

# %% [markdown]
# ### Getting the dataset
#
# Run the cell below to download the dataset from Kagglehub.  It will first download it to a temporary directory, but we'll move to a folder called 'cats_dogs_foxes' in your DATA_PATH directory. Along the way we do a couple of extra things:
# 1. rename a file that has an incorrect extension
# 2. delete two files that don't process correctly
# 3. resize the images so their shortest edge is at most 300 pixels to make experiments faster
#
# You only need to run this cell once, but it won't hurt if you run it again.
#
# Note:  resizing the images speeds up the Dataloaders below significantly because some of the original files were very large and had to opened and resized repeatedly for each training run.  When working with your own data you should consider preprocessing and saving the images before using them in your deep learning pipeline.

# %%
import kagglehub
import shutil
import os
from PIL import Image

# Define the destination path
destination_path = DATA_PATH / 'cats_dogs_foxes'

# Check if the destination path already exists
if destination_path.exists():
    print(f"Dataset already exists at: {destination_path}")
else:
    # Download latest version
    target_dataset = "snmahsa/animal-image-dataset-cats-dogs-and-foxes"
    path = kagglehub.dataset_download(target_dataset)
    print("Path to dataset files:", path)

    # Get the first folder in the downloaded path
    first_folder = next(os.scandir(path)).path

    # Rename and move the folder
    shutil.move(first_folder, destination_path)
    print(f"Dataset moved to: {destination_path}")

    # Split the path and remove everything at or deeper than 'snmahsa'
    path_parts = Path(path).parts
    snmahsa_index = path_parts.index('snmahsa')
    path_to_remove = Path(*path_parts[:snmahsa_index + 1])
    shutil.rmtree(path_to_remove)
    print(f"All files and folders in {path_to_remove} have been removed.")

    # Rename the file 'cat/cat006.jpg!d' to 'cat/cat006.jpg'
    file_to_rename = destination_path / 'cat/cat006.jpg!d'
    new_file_name = destination_path / 'cat/cat006.jpg'

    if file_to_rename.exists():
        file_to_rename.rename(new_file_name)
        print(f"Renamed {file_to_rename} to {new_file_name}")
    else:
        print(f"File {file_to_rename} does not exist.")

    # Delete the file 'cat/cat008.svg'
    file_to_delete = destination_path / 'cat/cat008.svg'
    if file_to_delete.exists():
        file_to_delete.unlink()
        print(f"Deleted {file_to_delete}")
    else:
        print(f"File {file_to_delete} does not exist.")

    # Delete the file 'fox/fox003.jpg'
    file_to_delete = destination_path / 'fox/fox003.jpg'
    if file_to_delete.exists():
        file_to_delete.unlink()
        print(f"Deleted {file_to_delete}")
    else:
        print(f"File {file_to_delete} does not exist.")

    # Resize images so the shortest edge is at most 300 pixels and save them as JPEGs
    for class_dir in destination_path.iterdir():
        if class_dir.is_dir():
            for img_path in class_dir.iterdir():
                if img_path.suffix.lower() in ['.jpg', '.jpeg', '.png']:
                    try:
                        with Image.open(img_path) as img:
                            # Calculate the new size while maintaining the aspect ratio
                            ratio = 300 / min(img.size)
                            new_size = (int(img.size[0] * ratio), int(img.size[1] * ratio))
                            img = img.resize(new_size, Image.LANCZOS)
                            
                            # Save the image as JPEG
                            img.save(img_path, format='JPEG')
                            print(f"Resized and saved {img_path}")
                    except Exception as e:
                        print(f"Error processing {img_path}: {e}")
                else:
                    print(f"Skipping unsupported file type: {img_path}")
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/snmahsa/animal-image-dataset-cats-dogs-and-foxes?dataset_version_number=1...
# 100%|██████████| 388M/388M [00:08<00:00, 45.8MB/s]
# Extracting files...
# Path to dataset files: C:\Users\bagge\.cache\kagglehub\datasets\snmahsa\animal-image-dataset-cats-dogs-and-foxes\versions\1
# Dataset moved to: C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes
# All files and folders in C:\Users\bagge\.cache\kagglehub\datasets\snmahsa have been removed.
# Renamed C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat006.jpg!d to C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat006.jpg
# Deleted C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat008.svg
# Deleted C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox003.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat001.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat002.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat003.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat004.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat005.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat006.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat007.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat009.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat010.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat011.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat012.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat013.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat014.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat015.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat016.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat017.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat018.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat019.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat020.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat021.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat022.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat023.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat024.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat025.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat026.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat027.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat028.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat029.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat030.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat031.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat032.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat033.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat034.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat035.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat036.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat037.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat038.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat039.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat040.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat041.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat042.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat043.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat044.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat045.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat046.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat047.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat048.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat049.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat050.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat051.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat052.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat053.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat054.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat055.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat056.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat057.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat058.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat059.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat060.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat061.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat062.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat063.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat064.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat065.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat066.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat067.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat068.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat069.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat070.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat071.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat072.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat073.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat074.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat075.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat076.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat077.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat078.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat079.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat080.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat081.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat082.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat083.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat084.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat085.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat086.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat087.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat088.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat089.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat090.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat091.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat092.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat093.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat094.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat095.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat096.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat097.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat098.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat099.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat100.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat101.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat102.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\cat\cat103.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog001.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog002.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog003.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog004.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog005.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog006.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog007.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog008.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog009.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog010.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog011.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog012.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog013.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog014.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog015.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog016.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog017.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog018.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog019.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog020.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog021.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog022.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog023.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog024.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog025.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog026.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog027.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog028.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog029.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog030.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog031.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog032.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog033.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog034.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog035.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog036.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog037.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog038.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog039.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog040.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog041.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog042.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog043.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog044.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog045.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog046.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog047.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog048.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog049.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog050.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog051.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog052.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog053.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog054.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog055.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog056.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog057.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog058.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog059.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog060.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog061.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog062.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog063.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog064.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog065.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog066.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog067.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog068.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog069.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog070.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog071.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog072.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog073.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog074.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog075.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog076.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog077.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog078.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog079.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog080.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog081.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog082.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog083.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog084.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog085.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog086.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog087.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog088.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog089.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog090.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog091.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog092.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog093.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog094.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog095.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog096.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog097.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog098.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog099.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog100.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog101.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog102.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog103.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog104.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\dog\dog105.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox001.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox002.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox004.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox005.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox006.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox007.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox008.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox009.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox010.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox011.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox012.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox013.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox014.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox015.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox016.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox017.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox018.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox019.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox020.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox021.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox022.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox023.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox024.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox025.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox026.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox027.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox028.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox029.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox030.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox031.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox032.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox033.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox034.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox035.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox036.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox037.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox038.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox039.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox040.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox041.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox042.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox043.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox044.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox045.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox046.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox047.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox048.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox049.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox050.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox051.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox052.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox053.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox054.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox055.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox056.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox057.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox058.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox059.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox060.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox061.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox062.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox063.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox064.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox065.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox066.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox067.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox068.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox069.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox070.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox071.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox072.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox073.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox074.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox075.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox076.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox077.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox078.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox079.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox080.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox081.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox082.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox083.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox084.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox085.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox086.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox087.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox088.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox089.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox090.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox091.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox092.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox093.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox094.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox095.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox096.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox097.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox098.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox099.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox100.jpg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox101.jpeg
# Resized and saved C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes\fox\fox102.jpg

# %% [markdown]
# ### Inspecting the data
#
# Let's look at a few of the images.  If you look at the dataset folder you'll see that the images are stored in directories for each class.  Like this:
#
# ```
# DATA_PATH
# └── cats_dogs_foxes
#     ├── cat
#     ├── dog
#     └── fox
# ```
#
# This is a common way to store image classification datasets and `torchvision.datasets.ImageFolder` makes it easy to create a PyTorch Dataset in this scenario.  Let's create the dataset and show some of the images.  By default, it will return PIL images, but our `create_image_grid` helper function can handle those.

# %%
full_dataset = ImageFolder( DATA_PATH / 'cats_dogs_foxes')
full_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 308
#     Root location: C:\Users\bagge\My Drive\Python_Projects\DS776_Develop_Project\data\cats_dogs_foxes

# %% [markdown]
# Run the cell below to create a 5x5 grid of randomly selected images from this dataset.

# %%
create_image_grid(full_dataset, nrows = 5, ncols = 5, img_size=(200,200), show_labels=True, pad=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1008x1068>

# %% [markdown]
# # Data Augmentation
#
# With such a small dataset we'll need to use agressive data augmentation to avoid overfitting.  Note that the animals tend to be centered in the photgraphs so to get the images to a uniform size of 224x224 we'll first resize the image so its shortest edge is 224 pixels, then crop the center of that image.  Later we apply a random crop with padding and a random rotation, both of which will introduce some black pixels on the borders of the transformed image.  An alternate way to hand handle the cropping and rotation would be to resize and center crop to a slightly larger size, like 256x256, then rotate and then do a random crop to 224x224.
#
# As you learn about data augmentation you may find it helpful to use ChatGPT or a similar AI to get suggestions.  For example, a prompt like this: "I have a tiny image dataset of foxes, cats, and dogs and want to fine-tune an image classification model.  Suggest separate training and validation transformation pipelines for data augmentation.  The images should be sized to 224x224 and normalized using Imagenet statistics.  Use torchvisions.transforms.v2" would give a starting point.

# %%
mean = [0.485, 0.456, 0.406]  # Example mean values, replace with yours if needed
std = [0.229, 0.224, 0.225]  # Example std values, replace with yours if needed

transform_train = T.Compose([
    T.ToImage(),
    T.ToDtype(torch.float32, scale=True),
    T.Resize(224, max_size=None),  # Resize so the shortest edge is 224
    T.CenterCrop(224),            # Center crop to 224x224
    T.RandomRotation(degrees=15),
    T.RandomCrop(224, padding=10),            # Random crop padded img to 224x224
    T.RandomHorizontalFlip(),
    T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    T.RandomGrayscale(),
    T.Normalize(mean=mean, std=std),
    T.ToPureTensor()
])

transform_val = T.Compose([
    T.ToImage(),
    T.ToDtype(torch.float32, scale=True),
    T.Resize(224, max_size=None),  # Resize so the shortest edge is 256
    T.CenterCrop(224),            # Center crop to 256x256
    T.Normalize(mean=mean, std=std),
    T.ToPureTensor()
])

# %%
full_train_dataset = ImageFolder(DATA_PATH / 'cats_dogs_foxes',transform=transform_train)
full_val_dataset = ImageFolder(DATA_PATH / 'cats_dogs_foxes', transform=transform_val)
train_indices, val_indices = train_test_split(list(range(len(full_train_dataset))), train_size=0.8, random_state=42)

train_dataset = Subset(full_train_dataset, train_indices)
val_dataset = Subset(full_val_dataset, val_indices)

# %% [markdown]
# Let's look at some of the images that have been transformed multiple times to get an idea of how the data augmentation is working.  If you execute the cell below again, you'll get a different set of images.

# %%
plot_transformed_images(train_dataset, img_size=(150,150), mean=mean, std=std)
# Out:
# <PIL.Image.Image image mode=RGB size=910x758>

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4)

# %% [markdown]
# ## Downloading and Preparing a Model for a New Task
#
# To adapt a model that has been pretrained on Imagenet to a new classification task we'll have to download the model and, at the very least, replace the final linear output layer with a new output layer that has the number of classes for its number of outputs.  We will probably also want to be able to identify freeze the base layers of the network (often called the "backbone") to prevent their weights from being updated in training.
#
# For our first example we'll use [ResNet18](https://paperswithcode.com/paper/deep-residual-learning-for-image-recognition) as the textbook did. It's a good, lightweight model that can establish a baseline for what you can do with transfer learning for your problem.

# %%
model = models.resnet18(weights="DEFAULT")
summary(model, 
        input_size=(32,3,224,224), 
        col_names=["input_size", "output_size", "num_params"], 
        row_settings=["var_names"],
        depth=1)
# Out:
# ===================================================================================================================
# Layer (type (var_name))                  Input Shape               Output Shape              Param #
# ===================================================================================================================
# ResNet (ResNet)                          [32, 3, 224, 224]         [32, 1000]                --
# ├─Conv2d (conv1)                         [32, 3, 224, 224]         [32, 64, 112, 112]        9,408
# ├─BatchNorm2d (bn1)                      [32, 64, 112, 112]        [32, 64, 112, 112]        128
# ├─ReLU (relu)                            [32, 64, 112, 112]        [32, 64, 112, 112]        --
# ├─MaxPool2d (maxpool)                    [32, 64, 112, 112]        [32, 64, 56, 56]          --
# ├─Sequential (layer1)                    [32, 64, 56, 56]          [32, 64, 56, 56]          147,968
# ├─Sequential (layer2)                    [32, 64, 56, 56]          [32, 128, 28, 28]         525,568
# ├─Sequential (layer3)                    [32, 128, 28, 28]         [32, 256, 14, 14]         2,099,712
# ├─Sequential (layer4)                    [32, 256, 14, 14]         [32, 512, 7, 7]           8,393,728
# ├─AdaptiveAvgPool2d (avgpool)            [32, 512, 7, 7]           [32, 512, 1, 1]           --
# ├─Linear (fc)                            [32, 512]                 [32, 1000]                513,000
# ===================================================================================================================
# Total params: 11,689,512
# Trainable params: 11,689,512
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 58.05
# ===================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 1271.92
# Params size (MB): 46.76
# Estimated Total Size (MB): 1337.94
# ===================================================================================================================

# %% [markdown]
# The layer we need to modify is that last Linear (fully-connected) layer in the last block.

# %%
model.fc
# Out:
# Linear(in_features=512, out_features=1000, bias=True)

# %% [markdown]
# We need to replace it with a Linear layer with 1024 inputs and 3 outputs for our 3 classes.  We'll read the number of inputs from the existing layer and change the last layer like this:

# %%
model.fc = nn.Linear(model.fc.in_features, 3)

# %% [markdown]
# We also want to freeze all of the base layers (those in the *features* block) which means we need to set the requires_grad attribute of all the parameter tensors to False in the base layers.  We could also freeze the first linear layer in the *classifier* block.  We experimented with both ways and it didn't seem to make much difference.  Here's the code we'll use to freeze all the layers in the "backbone" and not the layers in the "head":
#
# We also want to freeze all of the layers in the "backbone" except for the linear output layer.  This requires us to set the `requires_grad` attribue to all the parameter tensors to `False` except the classification "head" which in this case is the single output layer `model.fc`.  We'll do this by freezing all the layers in the model, then unfreezing model.fc.

# %%
# freeze all but the head
for param in model.parameters():
    param.requires_grad = False
for param in model.fc.parameters():
    param.requires_grad = True

# %% [markdown]
# When using transfer learning I find it helpful to build a custom model class to load the model, change the output layer to have the correct number of output, and to freeze and unfreeze the backbone.  ChatGPT or another AI can help you write it for all of the well established pre-trained models in torchvision.models.  Here is the prompt I used.
#
# "Write a PyTorch nn.Module class ResNet18Custom that modifies the final layer of resnet18 for a specified num_outputs.  Pass in weights, defaults to none, to load pretrained model weights.  Include methods to freeze all layers except the head (freeze_backbone) and to unfreeze all layers (unfreeze_backbone). Add docstrings for the class and its methods."
#
# After using the prompt, I tweaked a couple of things, but it made a great starting point.  Here is the code:

# %%
import torch
import torch.nn as nn
from torchvision.models import resnet18, ResNet18_Weights

class ResNet18Custom(nn.Module):
    """
    A custom ResNet18 model with a modified final layer for a specified number of output classes.

    Args:
        num_outputs (int): The number of output classes for the modified final layer.
        weights (ResNet18_Weights or None): Pretrained weights to load for ResNet18. If None, the model is randomly initialized.

    Methods:
        freeze_backbone(): Freezes all layers of the backbone except the final classification head.
        unfreeze_backbone(): Unfreezes all layers of the backbone.
    """
    def __init__(self, num_outputs: int, weights=None):
        """
        Initializes the ResNet18Custom model.

        Args:
            num_outputs (int): The number of output classes for the modified final layer.
            weights (ResNet18_Weights or None): Pretrained weights for ResNet18. Defaults to None.
        """
        super(ResNet18Custom, self).__init__()
        # Load ResNet18 with specified weights (pretrained or None)
        self.model = models.resnet18(weights=weights)
        
        # Replace the final fully connected layer to fit the desired output size
        in_features = self.model.fc.in_features
        self.model.fc = nn.Linear(in_features, num_outputs)

    def forward(self, x):
        """
        Forward pass of the model.

        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, channels, height, width).

        Returns:
            torch.Tensor: Output tensor of shape (batch_size, num_outputs).
        """
        return self.model(x)

    def freeze_backbone(self):
        """
        Freezes all layers of the backbone except the final classification head.
        This is useful for transfer learning scenarios where only the head is fine-tuned.
        """
        for param in self.backbone.parameters():
            param.requires_grad = False
        
        # Ensure the final fully connected layer remains trainable
        for param in self.backbone.fc.parameters():
            param.requires_grad = True

    def unfreeze_backbone(self):
        """
        Unfreezes all layers of the backbone, allowing the entire model to be fine-tuned.
        """
        for param in self.backbone.parameters():
            param.requires_grad = True

# %% [markdown]
# ## Training from Scratch

# %% [markdown]
# The dataset has only 307 images before splitting into training and validation sets so training any sort of CNN from scratch is unlikely to work well.  Let's try it anyway just to see what happens.
#
# Here we'll load the model without any pretrained model weights and train it for 40 epochs using our usual workflow.  Below we train for 40 epochs for illustration, but if you're running this code you can reduce that to see how it works.

# %%
model = ResNet18Custom(num_outputs=3)
loss_func = nn.CrossEntropyLoss()  # Cross-entropy loss for classification
optimizer = optim.AdamW(model.parameters())  # Adam optimizer

device = get_device()
print(device)

ckpt_file = MODELS_PATH / 'L05_animals_resnet18_from_scratch.pt'
epochs = 40

score_funcs = {'ACC':accuracy_score}
results = train_network(model,
                        loss_func,
                        train_loader,
                        device=device,
                        val_loader=val_loader,
                        epochs = epochs,
                        optimizer = optimizer,
                        score_funcs = score_funcs,
                        checkpoint_file=ckpt_file)
# Out:
# cuda
# Epoch: 100%|██████████| 40/40 [03:58<00:00,  5.96s/it, train_loss=0.538, val_loss=1.55]

# %%
ckpt_file = MODELS_PATH / 'L05_animals_resnet18_from_scratch.pt'
AdamW_augment = load_results(ckpt_file)

plot_training_metrics(AdamW_augment, [['train loss', 'val loss'], ['train ACC', 'val ACC']])

# %% [markdown]
# Training for 40 epochs was overkill, but we did it to illustrate the overfitting which is pretty clearly occuring in the first few epochs.  Notice that the model accuracy is about 50% on the validation set which is little better than guessing since there are only three classes in this data.  The model is slowly memorizing the training data and mostly failing to generalize to the validation data.  Training from scratch simply isn't going to work here.

# %% [markdown]
# ## Transfer Learning
#
# *Transfer learning* usually refers to the process of freezing the base layers of a model, replacing the output layer, and training just the output layer or perhaps all of the fully connected layers in the classification head.
#
# To do this here, we'll load the pretrained version of the model from torchvision.  The code to do that is in our custom model class, but it would normally look like this:
#
# ```python
# model = models.resnet18(weights="DEFAULT")
# ```
#
# Most common models in torchvision are pretrained on Imagenet and those weights can usually be loaded by specifying `weights="DEFAULT"`, but there are sometimes other choices of weights.  To learn more about pretrained models and their weights you can read the [Models and pre-trained weights](https://pytorch.org/vision/stable/models.html?utm_source=chatgpt.com) section of the PyTorch documentation.
#
# Here is a summary of how we'll do transfer learning using ResNet18 for our dataset:
# 1.  Instantiate our custom model with 3 classes and "DEFAULT" Imagenet weights
# 2.  Freeze everything but the output layer.
# 3.  Train that layer for 8 epochs with early stopping.
#
# Early stopping ensures that model with the best validation performance is saved and also helps to reduce overfitting by stopping when validation performance stops improving.

# %%
model = ResNet18Custom(num_outputs=3, weights = "DEFAULT")
model.freeze_backbone()

loss_func = nn.CrossEntropyLoss()  # Cross-entropy loss for classification
optimizer = optim.AdamW(model.parameters())  # Adam optimizer

device = get_device()
print(device)

ckpt_file = MODELS_PATH / 'L05_animals_resnet18_transfer_frozen_backbone.pt'
epochs = 8

score_funcs = {'ACC':accuracy_score}
results = train_network(model,
                        loss_func,
                        train_loader,
                        device=device,
                        val_loader=val_loader,
                        epochs = epochs,
                        optimizer = optimizer,
                        score_funcs = score_funcs,
                        checkpoint_file=ckpt_file,
                        early_stop_crit='max',
                        early_stop_metric='ACC',
                        patience=3)
# Out:
# cuda
# Epoch: 100%|██████████| 8/8 [00:43<00:00,  5.42s/it, train_loss=0.215, val_loss=0.284]

# %%
ckpt_file = MODELS_PATH / 'L05_animals_resnet18_transfer_frozen_backbone.pt'
results = load_results(ckpt_file)
results
# Out:
#    epoch  total time  train loss  val loss  train ACC   val ACC
# 0      0    2.837531    1.185347  0.955956   0.345528  0.483871
# 1      1    5.698352    0.782314  0.672232   0.703252  0.806452
# 2      2    8.607752    0.573351  0.562212   0.853659  0.806452
# 3      3   11.392990    0.416484  0.421253   0.934959  0.870968
# 4      4   14.184384    0.370142  0.372706   0.922764  0.870968
# 5      5   17.186067    0.285433  0.348815   0.951220  0.887097
# 6      6   20.215514    0.273002  0.283186   0.947154  0.935484

# %% [markdown]
# Wow!  Over 93% validation accuracy with almost no effort.  Notice that the training and validation losses are quite similar throughout the training which suggests we're not overfitting.
#
# After training the output layer we can try to *fine-tune* the whole model.  It's unlikely to work well here since we have so little training data, but we'll try it.  Here's what to do:
# 1. Load the model with the results of training with the frozen backbone.
# 2. Unfreeze the backbone.
# 3. Train it for a few epochs.  It's common to use a scheduler like OneCycleLR to accelerate convergence, but also to use a small learning rate because we don't want to change the base layers much.  If the base layers change too much we risk losing some of the pretrained model's ability to extract good features based on its pretraining.
#
# Again, we use early stopping to ensure that our best version of the model is saved.

# %%
# load the model with the frozen backbone and unfreeze it
model = load_model(ResNet18Custom(num_outputs=3), MODELS_PATH / 'L05_animals_resnet18_transfer_frozen_backbone.pt')
model.unfreeze_backbone()

# Configure Training for unfrozen model
ckpt_file = MODELS_PATH / 'L05_animals_resnet18_transfer_unfrozen_backbone.pt'
epochs = 3
optimizer = optim.AdamW(model.parameters())
scheduler = OneCycleLR(optimizer, max_lr=0.0001, epochs=epochs, steps_per_epoch=len(train_loader))
#scheduler = None

# Train and save
results = train_network(model,
                        loss_func,
                        train_loader,
                        device=device,
                        val_loader=val_loader,
                        epochs = epochs,
                        optimizer = optimizer,
                        score_funcs = score_funcs,
                        checkpoint_file=ckpt_file,
                        lr_schedule=scheduler,
                        scheduler_step_per_batch=True,
                        early_stop_crit='max',
                        early_stop_metric='ACC',
                        patience=1)
# Out:
# Epoch: 100%|██████████| 3/3 [00:16<00:00,  5.45s/it, train_loss=0.0538, val_loss=0.0977]

# %%
ckpt_file = MODELS_PATH / 'L05_animals_resnet18_transfer_unfrozen_backbone.pt'
results = load_results(ckpt_file)
results
# Out:
#    epoch  total time  train loss  val loss  train ACC   val ACC            lr
# 0      0    2.952316    0.179870  0.160252   0.971545  0.935484  9.719418e-05
# 1      1    5.915602    0.076462  0.104267   0.987805  0.967742  3.705930e-05
# 2      2    8.785928    0.053756  0.097746   0.995935  0.967742  8.720729e-07

# %% [markdown]
# If you run the last few cells over you'll likely get different results.  It can happen that you get the best results early from freezing the backbone or that the best results come from the finetuning we do with the unfrozen backbone.
#
# Assuming that the unfrozen backbone training gave the best result.  Let's load and evaluate that model:

# %%
model = load_model(ResNet18Custom(num_outputs=3), MODELS_PATH / 'L05_animals_resnet18_transfer_unfrozen_backbone.pt')
device = get_device()
conf_mat,report,misses_dataset=evaluate_classifier(model, val_dataset, device)
# Out:
# The dataset has 62 samples.
# The model misclassified 2 samples.

# %%
# show the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          cat       1.00      1.00      1.00        23
#          dog       0.95      0.95      0.95        21
#          fox       0.94      0.94      0.94        18
#
#     accuracy                           0.97        62
#    macro avg       0.97      0.97      0.97        62
# weighted avg       0.97      0.97      0.97        62

# %%
create_image_grid(misses_dataset, nrows=2, ncols=5, img_size=(200, 200), show_labels=True, mean=mean, std=std)
# Out:
# <PIL.Image.Image image mode=RGB size=402x212>

# %% [markdown]
# ## Using other models
#
# While the pretrained ResNet18 model did a pretty amazing job on our dataset, it's possible that a larger or more modern or larger model could improve the performance. Since ResNet was introduced in 2015 image classification models have continued to advance.
#
# To get a summary of recent advancements try asking an AI to "briefly summarize, in chronological order, the most important and widely used advancements in image classification models since ResNet".   One of the models that should be mentioned in that list is ConvNeXt which is a state-of-the-art CNN model.
#
# Here we'll illustrate how easy it to apply the smallest pre-trained ConvNeXt model to our dataset.  We'll start by building a custom class to load and modify the smallest ConvNeXt model and to provide methods for freezing and unfreezing the backbone.  One easy way to do this is to ask an AI to modify your the ResNet18Custom class from above to work with the smallest ConvNeXT model.

# %%
class ConvNeXtTinyCustom(nn.Module):
    """
    Custom ConvNeXt-Tiny model for a specified number of output classes.

    Attributes:
        model (torchvision.models.ConvNeXt): The ConvNeXt-Tiny model with a modified final layer.
        num_outputs (int): Number of output classes.
    """
    def __init__(self, num_outputs: int, weights=None):
        """
        Initializes the ConvNeXt-Tiny model and modifies the final layer.

        Args:
            num_outputs (int): The number of output classes for the modified ConvNeXt-Tiny model.
            weights: Pretrained weights to load into the model. Defaults to None.
        """
        super(ConvNeXtTinyCustom, self).__init__()
        self.num_outputs = num_outputs
        # Load ConvNeXt-Tiny model with specified weights
        self.model = models.convnext_tiny(weights=weights)
        # Replace the final classification head
        in_features = self.model.classifier[2].in_features
        self.model.classifier[2] = nn.Linear(in_features, num_outputs)

    def freeze_backbone(self):
        """
        Freezes all layers of the backbone except the final classification head.

        This method sets `requires_grad` to `False` for all layers except the final classification layer.
        """
        for param in self.model.parameters():
            param.requires_grad = False
        # Unfreeze the final fully connected layer
        for param in self.model.classifier[2].parameters():
            param.requires_grad = True

    def unfreeze_backbone(self):
        """
        Unfreezes all layers of the ConvNeXt-Tiny backbone.

        This method sets `requires_grad` to `True` for all layers.
        """
        for param in self.model.parameters():
            param.requires_grad = True

    def forward(self, x):
        """
        Forward pass of the model.

        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, channels, height, width).
        
        Returns:
            torch.Tensor: Output tensor of shape (batch_size, num_outputs).
        """
        return self.model(x)

# %% [markdown]
# Now we'll follow the same steps we used to for transfer learning with ResNet18.

# %%
model = ConvNeXtTinyCustom(num_outputs=3, weights = "DEFAULT")
model.freeze_backbone()

loss_func = nn.CrossEntropyLoss()  # Cross-entropy loss for classification
optimizer = optim.AdamW(model.parameters())  # Adam optimizer

device = get_device()
print(device)

ckpt_file = MODELS_PATH / 'L05_animals_convnexttiny.pt'
epochs = 8

score_funcs = {'ACC':accuracy_score}
results = train_network(model,
                        loss_func,
                        train_loader,
                        device=device,
                        val_loader=val_loader,
                        epochs = epochs,
                        optimizer = optimizer,
                        score_funcs = score_funcs,
                        checkpoint_file=ckpt_file,
                        early_stop_crit='max',
                        early_stop_metric='ACC',
                        patience=2)
# Out:
# cuda
# Epoch: 100%|██████████| 8/8 [00:44<00:00,  5.52s/it, train_loss=0.0784, val_loss=0.102]

# %%
ckpt_file = MODELS_PATH / 'L05_animals_convnexttiny.pt'
results = load_results(ckpt_file)
results
# Out:
#    epoch  total time  train loss  val loss  train ACC   val ACC
# 0      0    3.052534    0.769881  0.543621   0.849593  0.935484
# 1      1    5.921638    0.394595  0.317853   0.979675  0.967742
# 2      2    8.790700    0.225042  0.219017   1.000000  0.983871
# 3      3   11.601023    0.153618  0.169229   0.995935  0.983871
# 4      4   14.437995    0.112324  0.140297   1.000000  0.983871
# 5      5   17.249849    0.088227  0.123214   1.000000  0.983871
# 6      6   20.236283    0.070120  0.110894   1.000000  0.983871
# 7      7   23.239143    0.078368  0.101721   0.987805  0.983871

# %%
model = load_model(ConvNeXtTinyCustom(num_outputs=3), MODELS_PATH / 'L05_animals_convnexttiny.pt')
device = get_device()
conf_mat,report,missed_dataset=evaluate_classifier(model, val_dataset, device, img_size=(5,5))
# Out:
# The dataset has 62 samples.
# The model misclassified 1 samples.

# %%
create_image_grid(missed_dataset, nrows=1, ncols=2, img_size=(150, 150), show_labels=True, mean=mean, std=std)
# Out:
# <PIL.Image.Image image mode=RGB size=150x162>

# %% [markdown]
# With just a little training the ConvNeXt model was able to correctly classify all but one dog.  That's pretty amazing.
#
# This dataset is pretty easy since it contains images that are very similar those in the ImageNet training set. In the homework we'll have you explore transfer learning using a larger dataset that is a bit further from ImageNet.
