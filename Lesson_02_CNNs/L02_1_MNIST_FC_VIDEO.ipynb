# %%
# %pip install -q ../introdl
# Out:
# WARNING: Error parsing dependencies of pytorch-lightning: .* suffix can only be used with `==` or `!=` operators
#     torch (>=1.9.*)
#            ~~~~~~^
# Note: you may need to restart the kernel to use updated packages.

# %%
# configuration
data_dir = '../../data' # directory to save data - change as needed

# %%
# imports

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display, HTML

sns.set_theme(style='whitegrid')

plt.rcParams['figure.figsize'] = [8, 6]  # Set the default figure size (width, height) in inches

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from torchinfo import summary

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader

import torchvision.transforms as transforms
from torchvision.datasets import MNIST
from torchvision.utils import make_grid

from introdl.utils import get_device, load_results, load_model
from introdl.idlmam import train_network
from introdl.visul import show_image_grid, plot_training_metrics

# %% [markdown]
# # MNIST Handwritten Digit Classification

# %% [markdown]
# ## MNIST Handwritten Digits
#
# * 70,000 handwritten digits (0-9).
# * Modified National Institute of Standards and Technology dataset.
# * Compiled by **Yann LeCun**, Corinna Cortes, and Christopher J.C. Burges.
# * First application of Convolutional Neural Networks.  [Original 1998 paper](http://vision.stanford.edu/cs598_spring07/papers/Lecun98.pdf)

# %%
# Define the transform to convert images to tensor and normalize them
transform = transforms.Compose([
    transforms.ToTensor(),
])

# Load the MNIST dataset
mnist_dataset = MNIST(root=data_dir, train=True, download=True, transform=transform)

# Example: Display a grid of MNIST digits

show_image_grid(5,10,mnist_dataset,cmap='gray', dark_mode=True, fig_scale=.8)

# %% [markdown]
# The background in grayscale images is usually represented by zeros which are often interpreted as black in grayscale colormaps.  If you would prefer to have the digits look like they are drawn on paper you can choose a reversed colormap:

# %%
show_image_grid(5,10,mnist_dataset,cmap='Greys',dark_mode=False,fig_scale=.8)

# %% [markdown]
# ## Image Data

# %%
# Load the MNIST dataset
mnist_dataset = MNIST(root=data_dir, train=True, download=True)

# Get an image (you can choose any image)
image, label = mnist_dataset[7]

# Convert the PIL image to a NumPy array
image_np = np.array(image)

# Select a portion of the image (e.g., rows 10 to 40 and columns 10 to 40)
df = pd.DataFrame(image_np[4:26,4:24])

# Apply styling to the DataFrame
styled_df = df.style.set_properties(**{
    'font-size': '8pt', 
    'border-collapse': 'collapse',
    'border': '1px solid black',
    'height': '22px',
    'width': '22px'
}).background_gradient(cmap='gray').set_table_styles([
    {'selector': 'td', 'props': [('border', '1px solid black')]}
]).hide(axis='index').hide(axis='columns')

# Display the styled DataFrame
from IPython.display import display
display(styled_df)
# Out:
# <style type="text/css">
# #T_40ee4 td {
#   border: 1px solid black;
# }
# #T_40ee4_row0_col0, #T_40ee4_row0_col1, #T_40ee4_row0_col2, #T_40ee4_row0_col3, #T_40ee4_row0_col4, #T_40ee4_row0_col5, #T_40ee4_row0_col6, #T_40ee4_row0_col7, #T_40ee4_row0_col8, #T_40ee4_row0_col9, #T_40ee4_row0_col10, #T_40ee4_row0_col11, #T_40ee4_row0_col12, #T_40ee4_row0_col13, #T_40ee4_row0_col14, #T_40ee4_row0_col15, #T_40ee4_row0_col16, #T_40ee4_row0_col17, #T_40ee4_row0_col18, #T_40ee4_row0_col19, #T_40ee4_row1_col0, #T_40ee4_row1_col1, #T_40ee4_row1_col2, #T_40ee4_row1_col3, #T_40ee4_row1_col4, #T_40ee4_row1_col5, #T_40ee4_row1_col6, #T_40ee4_row1_col18, #T_40ee4_row1_col19, #T_40ee4_row2_col0, #T_40ee4_row2_col1, #T_40ee4_row2_col2, #T_40ee4_row2_col3, #T_40ee4_row2_col4, #T_40ee4_row2_col19, #T_40ee4_row3_col0, #T_40ee4_row3_col1, #T_40ee4_row3_col2, #T_40ee4_row3_col3, #T_40ee4_row3_col4, #T_40ee4_row3_col19, #T_40ee4_row4_col0, #T_40ee4_row4_col1, #T_40ee4_row4_col2, #T_40ee4_row4_col3, #T_40ee4_row4_col4, #T_40ee4_row4_col19, #T_40ee4_row5_col0, #T_40ee4_row5_col1, #T_40ee4_row5_col2, #T_40ee4_row5_col3, #T_40ee4_row5_col4, #T_40ee4_row5_col9, #T_40ee4_row5_col10, #T_40ee4_row5_col11, #T_40ee4_row5_col12, #T_40ee4_row5_col19, #T_40ee4_row6_col0, #T_40ee4_row6_col1, #T_40ee4_row6_col2, #T_40ee4_row6_col3, #T_40ee4_row6_col4, #T_40ee4_row6_col5, #T_40ee4_row6_col6, #T_40ee4_row6_col7, #T_40ee4_row6_col8, #T_40ee4_row6_col9, #T_40ee4_row6_col10, #T_40ee4_row6_col11, #T_40ee4_row6_col12, #T_40ee4_row6_col18, #T_40ee4_row6_col19, #T_40ee4_row7_col0, #T_40ee4_row7_col1, #T_40ee4_row7_col2, #T_40ee4_row7_col3, #T_40ee4_row7_col4, #T_40ee4_row7_col5, #T_40ee4_row7_col6, #T_40ee4_row7_col7, #T_40ee4_row7_col8, #T_40ee4_row7_col9, #T_40ee4_row7_col10, #T_40ee4_row7_col11, #T_40ee4_row7_col18, #T_40ee4_row7_col19, #T_40ee4_row8_col0, #T_40ee4_row8_col1, #T_40ee4_row8_col2, #T_40ee4_row8_col3, #T_40ee4_row8_col4, #T_40ee4_row8_col5, #T_40ee4_row8_col6, #T_40ee4_row8_col7, #T_40ee4_row8_col8, #T_40ee4_row8_col9, #T_40ee4_row8_col18, #T_40ee4_row8_col19, #T_40ee4_row9_col0, #T_40ee4_row9_col1, #T_40ee4_row9_col2, #T_40ee4_row9_col3, #T_40ee4_row9_col4, #T_40ee4_row9_col17, #T_40ee4_row9_col18, #T_40ee4_row9_col19, #T_40ee4_row10_col0, #T_40ee4_row10_col1, #T_40ee4_row10_col2, #T_40ee4_row10_col3, #T_40ee4_row10_col15, #T_40ee4_row10_col16, #T_40ee4_row10_col17, #T_40ee4_row10_col18, #T_40ee4_row10_col19, #T_40ee4_row11_col0, #T_40ee4_row11_col1, #T_40ee4_row11_col2, #T_40ee4_row11_col3, #T_40ee4_row11_col16, #T_40ee4_row11_col17, #T_40ee4_row11_col18, #T_40ee4_row11_col19, #T_40ee4_row12_col0, #T_40ee4_row12_col1, #T_40ee4_row12_col2, #T_40ee4_row12_col3, #T_40ee4_row12_col4, #T_40ee4_row12_col16, #T_40ee4_row12_col17, #T_40ee4_row12_col18, #T_40ee4_row12_col19, #T_40ee4_row13_col0, #T_40ee4_row13_col1, #T_40ee4_row13_col2, #T_40ee4_row13_col3, #T_40ee4_row13_col4, #T_40ee4_row13_col5, #T_40ee4_row13_col6, #T_40ee4_row13_col7, #T_40ee4_row13_col8, #T_40ee4_row13_col9, #T_40ee4_row13_col10, #T_40ee4_row13_col11, #T_40ee4_row13_col16, #T_40ee4_row13_col17, #T_40ee4_row13_col18, #T_40ee4_row13_col19, #T_40ee4_row14_col0, #T_40ee4_row14_col1, #T_40ee4_row14_col2, #T_40ee4_row14_col3, #T_40ee4_row14_col4, #T_40ee4_row14_col5, #T_40ee4_row14_col6, #T_40ee4_row14_col7, #T_40ee4_row14_col8, #T_40ee4_row14_col9, #T_40ee4_row14_col10, #T_40ee4_row14_col11, #T_40ee4_row14_col16, #T_40ee4_row14_col17, #T_40ee4_row14_col18, #T_40ee4_row14_col19, #T_40ee4_row15_col0, #T_40ee4_row15_col1, #T_40ee4_row15_col5, #T_40ee4_row15_col6, #T_40ee4_row15_col7, #T_40ee4_row15_col8, #T_40ee4_row15_col9, #T_40ee4_row15_col10, #T_40ee4_row15_col16, #T_40ee4_row15_col17, #T_40ee4_row15_col18, #T_40ee4_row15_col19, #T_40ee4_row16_col0, #T_40ee4_row16_col5, #T_40ee4_row16_col6, #T_40ee4_row16_col7, #T_40ee4_row16_col8, #T_40ee4_row16_col16, #T_40ee4_row16_col17, #T_40ee4_row16_col18, #T_40ee4_row16_col19, #T_40ee4_row17_col0, #T_40ee4_row17_col15, #T_40ee4_row17_col16, #T_40ee4_row17_col17, #T_40ee4_row17_col18, #T_40ee4_row17_col19, #T_40ee4_row18_col0, #T ...
#   font-size: 8pt;
#   border-collapse: collapse;
#   border: 1px solid black;
#   height: 22px;
#   width: 22px;
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_40ee4_row1_col7 {
#   font-size: 8pt;
#   border-collapse: collapse;
#   border: 1px solid black;
#   height: 22px;
#   width: 22px;
#   background-color: #262626;
#   color: #f1f1f1;
# }
# #T_40ee4_row1_col8, #T_40ee4_row2_col5 {
#   font-size: 8pt;
#   border-collapse: collapse;
#   border: 1px solid black;
#   height: 22px;
#   width: 22px;
#   background-color: #2b2b2b;
#   color: #f1f1f1;
# }
# #T_40ee4_row1_col9 {
#   font-size: 8pt;
#   border-collapse: collapse;
#   border: 1px solid black;
#   height: 22px;
#   width: 22px;
#   background-color: #6a6a6a;
#   color: #f1f1f1;
# }
# #T_40ee4_row1_col10, #T_40ee4_row1_col11, #T_40ee4_row1_col12, #T_40ee4_row1_col13, #T_40ee4_row1_col14, #T_40ee4_row1_col15, #T_40ee4_row2_col16, #T_40ee4_row3_col16, #T_40ee4_row3_col17, #T_40ee4_row3_col18, #T_40ee4_row4_col16, #T_40ee4_row4_col17, #T_40ee4_row4_col18, #T_40ee4_row5_col16, #T_40ee4_row6_col16, #T_40ee4_row7_col16, #T_40ee4_row11_col6, #T_40ee4_row11_col7, #T_40ee4_row11_col8, #T_40ee4_row11_col9, #T_40ee4_row11_col10, #T_40ee4_row11_col11, #T_40ee4_row11_col12, #T_40ee4_row11_col13, #T_40ee4_row11_col14, #T_40ee4_row16_col3, #T_40ee4_row17_col1, #T_40ee4_row17_col2, #T_40ee4_row17_col3, #T_40ee4_row18_col1, #T_40ee4_row18_col2, #T_40ee4_row18_col3, #T_40ee4_row18_col4, #T_40ee4_row18_col5, #T_40ee4_row19_col3, #T_40ee4_row19_col4, #T_40ee4_row19_col5, #T_40ee4_row20_col5 {
#   font-size: 8pt;
#   border-collapse: collapse;
#   border: 1px solid black;
#   height: 22px;
#   width: 22px;
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_40ee4_row1_col16 {
#   font-size: 8pt;
#   border-collapse: collapse;
#   border: 1px solid black;
#   height: 22px;
#   width: 22px;
#   background-color: #b0b0b0;
#   color: #000000;
# }
# #T_40ee4_row1_col17 {
#   font-size: 8pt;
#   border-collapse: collapse;
#   border: 1px solid black;
#   height: 22px;
#   width: 22px;
#   background-color: #060606;
#   color: #f1f1f1;
# }
# #T_40ee4_row2_col6 {
#   font-size: 8pt;
#   border-collapse: collapse;
#   border: 1px solid black;
#   height: 22px;
#   width: 22px;
#   background-color: #8c8c8c;
#   color: #f1f1f1;
# }
# #T_40ee4_row2_col7, #T_40ee4_row11_col5 {
#   font-size: 8pt;
#   border-collapse: collapse;
#   border: 1px solid black;
#   height: 22px;
#   width: 22px;
#   background-color: #e2e2e2;
#   color: #000000;
# }
# #T_40ee4_row2_col8, #T_40ee4_row5_col14 {
#   font-size: 8pt;
#   border-collapse: collapse;
#   border: 1px solid black;
#   height: 22px;
#   width: 22px;
#   background-color: #e4e4e4;
#   color: #000000;
# }
# #T_40ee4_row2_col9, #T_40ee4_row2_col11, #T_40ee4_row2_col12, #T_40ee4_row2_col13, #T_40ee4_row2_col14, #T_40ee4_row2_col15, #T_40ee4_row3_col6, #T_40ee4_row3_col7, #T_40ee4_row3_col8, #T_40ee4_row3_col9, #T_40ee4_row3_col11, #T_40ee4_row3_col12, #T_40ee4_row3_col13, #T_40ee4_row3_col14, #T_40ee4_row3_col15, #T_40e

# %% [markdown]
# ## The PyTorch MNIST Dataset
#
# In the previous slide we loaded the MNIST dataset with this code:
#
# ```python
# mnist_dataset = MNIST(root=data_dir, train=True, download=True)
# ```
#
# The dataset object is an iterable that takes an index and returns an image and a label:

# %%
image, label = mnist_dataset[7]
type(image), type(label)
# Out:
# (PIL.Image.Image, int)

# %%
image
# Out:
# <PIL.Image.Image image mode=L size=28x28>

# %% [markdown]
# ## Normalizing Pixel Values
#
# - **Normalization** scales the pixel values to a desired range.
#
# ### Why Normalize?
# - **Improves model performance** by speeding up convergence.
# - Helps the model **handle features at different scales**.
#
# ### Common Methods:
#
# 1. **Scaling to [0, 1]**:
#    - Using `transforms.ToTensor()` in PyTorch:
#      ```python
#      transforms.ToTensor()  # Scales pixel values from [0, 255] to [0, 1]
#      ```
#
# 2. **Normalizing to mean 0 and std 1**:
#    - This further centers the data with mean **0** and standard deviation **1**:
#      ```python
#      transforms.Normalize((0.1307,), (0.3081,))  # Mean and std for MNIST
#      ```

# %% [markdown]
# ## Setup the data

# %%
# Define transformations for the training and test sets
transform = transforms.Compose([
    transforms.ToTensor(),           # Convert images to PyTorch tensors
    transforms.Normalize((0.1307,), (0.3081,))  # Normalize with mean and std of MNIST dataset
])

# Download and load the training dataset
train_dataset = MNIST(root=data_dir, train=True, download=True, transform=transform)
train_loader = DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)

# Download and load the test dataset
test_dataset = MNIST(root=data_dir, train=False, download=True, transform=transform)
test_loader = DataLoader(dataset=test_dataset, batch_size=1000, shuffle=False)

# %%
x,y=next(iter(train_loader))
x.shape
# Out:
# torch.Size([64, 1, 28, 28])

# %% [markdown]
# ## Define the model

# %%
class FullyConnectedNN(nn.Module):
    def __init__(self):
        super(FullyConnectedNN, self).__init__()
        self.net = nn.Sequential(
            nn.Flatten(),             # Flatten the input image to a vector
            nn.Linear(28 * 28, 128),  # Input layer (28x28 pixels) -> hidden layer
            nn.ReLU(),                # Apply ReLU activation function
            nn.Linear(128, 64),       # Hidden layer -> another hidden layer
            nn.ReLU(),                # Apply ReLU activation function
            nn.Linear(64, 10)         # Hidden layer -> output layer (10 classes)
            #nn.Softmax(dim=1)        # Convert logits to "probabilities" - in CE Loss function
            )
    
    def forward(self, x):
        return self.net(x)

# Initialize the model
model = FullyConnectedNN()

# %% [markdown]
# ## Model Summary

# %%
from torchinfo import summary #may need to install torchinfo first

batch_size = 40
summary(model, input_size = (64,1,28,28), col_width=16,
        col_names = ["input_size","output_size","num_params"])
# Out:
# ========================================================================================
# Layer (type:depth-idx)                   Input Shape      Output Shape     Param #
# ========================================================================================
# FullyConnectedNN                         [64, 1, 28, 28]  [64, 10]         --
# ├─Sequential: 1-1                        [64, 1, 28, 28]  [64, 10]         --
# │    └─Flatten: 2-1                      [64, 1, 28, 28]  [64, 784]        --
# │    └─Linear: 2-2                       [64, 784]        [64, 128]        100,480
# │    └─ReLU: 2-3                         [64, 128]        [64, 128]        --
# │    └─Linear: 2-4                       [64, 128]        [64, 64]         8,256
# │    └─ReLU: 2-5                         [64, 64]         [64, 64]         --
# │    └─Linear: 2-6                       [64, 64]         [64, 10]         650
# ========================================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 7.00
# ========================================================================================
# Input size (MB): 0.20
# Forward/backward pass size (MB): 0.10
# Params size (MB): 0.44
# Estimated Total Size (MB): 0.74
# ========================================================================================

# %% [markdown]
# ## Define the model - version 2

# %%
class FullyConnectedNN(nn.Module):
    def __init__(self):
        super(FullyConnectedNN, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 128)  # Input layer (28x28 pixels) -> hidden layer
        self.fc2 = nn.Linear(128, 64)       # Hidden layer -> another hidden layer
        self.fc3 = nn.Linear(64, 10)        # Hidden layer -> output layer (10 classes)
    
    def forward(self, x):
        x = x.view(-1, 28 * 28)  # Flatten the input image to a vector
        x = F.relu(self.fc1(x))   # Apply ReLU activation function
        x = F.relu(self.fc2(x))   # Apply ReLU activation function
        x = self.fc3(x)           # Output layer (logits)
        return x

# Initialize the model
model = FullyConnectedNN()

# %% [markdown]
# ## Setup training

# %% [markdown]
# We're going to cheat a bit here and use a variant of gradient descent called the AdamW optimizer.  We'll talk more about optimizers in lesson 3, but it would be a shame to wait until then to use it because it's much more efficient than vanilla gradient descent.

# %%
loss_func = nn.CrossEntropyLoss()  # Cross-entropy loss for classification
optimizer = optim.AdamW(model.parameters())  # AdamW optimizer, default lr=0.001

device = get_device()
print(device)

ckpt_file = 'models/model_MNIST_FC.pt'
epochs = 10

score_funcs = {'ACC':accuracy_score}
# Out:
# mps

# %% [markdown]
# ## Train

# %%
results_MNIST_FC = train_network(model,
                                 loss_func,
                                 train_loader,
                                 device=device,
                                 test_loader=test_loader,
                                 epochs = epochs,
                                 optimizer = optimizer,
                                 score_funcs = score_funcs,
                                 checkpoint_file=ckpt_file)
# Out:
# Epoch: 100%|██████████| 10/10 [01:17<00:00,  7.79s/it]

# %% [markdown]
# ## Results
#
# We get 97% to 98% accuracy on the validation set after only a few epochs!

# %%
ckpt_file = 'models/model_MNIST_FC.pt'
results_MNIST_FC = load_results(ckpt_file)

results_MNIST_FC
# Out:
#    epoch  total time  train loss  test loss  train ACC  test ACC
# 0      0    7.947635    0.267468   0.130003   0.919900    0.9614
# 1      1   15.272612    0.115224   0.108861   0.964417    0.9660
# 2      2   22.539809    0.078715   0.083711   0.975283    0.9739
# 3      3   29.651535    0.062762   0.095574   0.979700    0.9693
# 4      4   36.677669    0.050296   0.087906   0.983650    0.9712
# 5      5   43.794656    0.042241   0.082142   0.986550    0.9760
# 6      6   50.861038    0.035643   0.078243   0.988250    0.9776
# 7      7   57.881513    0.029904   0.111546   0.990433    0.9706
# 8      8   65.011669    0.025271   0.102678   0.991650    0.9739
# 9      9   72.129548    0.023061   0.101198   0.992183    0.9736

# %% [markdown]
# You can also view the results graphically if you would prefer.

# %%
plot_training_metrics(results_MNIST_FC, [['train loss', 'test loss'], ['train ACC', 'test ACC']])

# %% [markdown]
# After epoch 2 (the third epoch, silly Python indexing ...) there is some evidence of mild overfitting since the training loss continues to decrease while the test loss remains constant.  This indicates that the network is memorizing details of the training set instead of learning to generalize.  Though it's pretty amazing that we have greater than 97% accuracy on the test set without much effort!
#
# We could simply stop the training after the third epoch.  We'll see more about dealing with overfitting in the next lesson.

# %% [markdown]
# ### Evaluating the Model
#
# Greater than 97% accuracy is pretty amazing for our first effort.  Whenever you're working on a model it's important to understand the instances that the model predicts incorrectly.  Sometimes this gives insight into how the model can be improved.
#
# The code below shows how to loop over the test dataset and collect all the labels, predictions, and misclassified images. It also displays the confusion matrix.  Inspect the confusion matrix to look for common errors.  For example nines are frequently misclassified as fours.

# %%
device = get_device()
model = load_model(FullyConnectedNN, 'models/model_MNIST_FC.pt', device)

# Set the model to evaluation mode
model.eval()

# Collect the labels, predicted labels, and misclassified images
labels = []
pred_labels = []
misclassified_images = []
misclassified_true_labels = []
misclassified_pred_labels = []

# Iterate over the test dataset
for images, targets in test_loader:
    # Move the images and targets to the device
    images = images.to(device)
    targets = targets.to(device)
    
    # Forward pass
    outputs = model(images)
    
    # Get the predicted labels
    _, predicted = torch.max(outputs.data, 1)
    
    # Append the labels and predicted labels to the lists
    labels.extend(targets.cpu().numpy())
    pred_labels.extend(predicted.cpu().numpy())
    
    # Collect misclassified images
    for i in range(len(targets)):
        if targets[i] != predicted[i]:
            misclassified_images.append(images[i].cpu().numpy())
            misclassified_true_labels.append(targets[i].item())
            misclassified_pred_labels.append(predicted[i].item())

# Print the total number of images and the number of misclassified images
total_images = len(labels)
num_misclassified = len(misclassified_images)
print(f'Total number of images: {total_images}')
print(f'Number of misclassified images: {num_misclassified}')

# Compute the confusion matrix
confusion_mat = confusion_matrix(labels, pred_labels)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_mat)
disp.plot()
plt.show()
# Out:
# Total number of images: 10000
# Number of misclassified images: 233

# %% [markdown]
# It's a good idea to look at the images that are misclassified.  Running the cell below will display 25 misclassified digits selected at random.  Are you surprised by any of the misclassifications? Run the cell repeatedly to see different samples of misclassified digits.

# %%
# Plot a random sample of 25 misclassified images (or fewer if there aren't 25), ordered by true label
num_images_to_plot = min(25, num_misclassified)
random_indices = np.random.choice(num_misclassified, num_images_to_plot, replace=False)

# Sort the selected misclassified images by their true labels
sorted_indices = sorted(random_indices, key=lambda i: misclassified_true_labels[i])

num_cols = 5
num_rows = (num_images_to_plot + num_cols - 1) // num_cols
fig, axes = plt.subplots(num_rows, num_cols, figsize=(5, num_rows))
axes = axes.flatten()

for i in range(num_rows * num_cols):
    if i < num_images_to_plot:
        idx = sorted_indices[i]
        image = misclassified_images[idx].squeeze()  # Remove channel dimension if present
        true_label = misclassified_true_labels[idx]
        pred_label = misclassified_pred_labels[idx]
        
        axes[i].imshow(image, cmap='gray')
        axes[i].set_title(f'{true_label},{pred_label}')
        axes[i].axis('off')
    else:
        axes[i].axis('off')

plt.tight_layout()
plt.show()
